# %% [markdown]
# Hotel Prices Webscraper Decolar x CVC

# %%
# !pip install selenium
# !apt-get update 
# !apt install chromium-chromedriver
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (4.0.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.19.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (35.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.21)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:8 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 252 kB in 3s (98.7 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (95.0.4638.69-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 61 not upgraded.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import *
from time import sleep
import pandas as pd
import os

# %%
# Lista IDs destinos

# ID destinos CVC
  #Aracaju: 8726
  #Arraial dAjuda: 35727
  #Balneario Camboriu: 33964
  #Belo Horizonte: 2920
  #Brasilia: 1911
  #Buzios: 36132
  #Cabo Frio: 6940
  #Caldas Novas: 2263
  #Campinas: 8983
  #Campos do Jordao: 8986
  #Canela: 7538
  #Curitiba: 6162
  #Florianopolis: 8400
  #Fortaleza: 1463
  #Foz do Iguacu: 6236
  #Gramado: 7752
  #Ilhabela: 9172
  #Ilheus: 747
  #Joao Pessoa: 5104
  #Maceio: 185
  #Morro de Sao Paulo: 938
  #Natal: 34584
  #Porto Alegre: 8002
  #Porto de Galinhas: 5648
  #Porto Seguro: 1032
  #Praia de Pipa: 7299
  #Recife: 5541
  #Rio de Janeiro: 7110
  #Salvador: 1076
  #Sao Paulo: 9626

# ID destinos Decolar
  #Aracaju: 180
  #Arraial dAjuda: 339
  #Balneario Camboriu: 192594
  #Belo Horizonte: 701
  #Brasilia: 926
  #Buzios: 1077
  #Cabo Frio: 1227
  #Caldas Novas: 1364
  #Campinas: 1467
  #Campos do Jordao: 6116
  #Canela: 6064
  #Curitiba: 1595
  #Florianopolis: 2261
  #Fortaleza: 2302
  #Foz do Iguacu: 3072
  #Gramado: 2611
  #Ilhabela: 3027
  #Ilheus: 3158
  #Joao Pessoa: 3399
  #Maceio: 4430
  #Morro de Sao Paulo: 4678
  #Natal: 4971
  #Porto Alegre: 5822
  #Porto de Galinhas: 5648
  #Porto Seguro: 881
  #Praia de Pipa: 5875
  #Recife: 6322
  #Rio de Janeiro: 6381
  #Salvador: 7018
  #Sao Paulo: 6574

# %%
# Parâmetros

nome_destino = 'Balneario Camboriu'
id_destino_cvc = '33964'
id_destino_decolar = '192594'
checkin = '2021-11-28' # Formato AAAA-MM-DD
checkout = '2021-11-30' # Formato AAAA-MM-DD
pax = '2' # Número de hóspedes (adultos)

# %%
# Definições Chromedriver

chrome_options = webdriver.ChromeOptions()
chrome_options.add_experimental_option('excludeSwitches', ['enable-logging'])
chrome_options.add_argument('--lang=pr-BR')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# %%
# Scrape CVC

nome_hoteis_cvc = []
preco_hoteis_cvc = []

class ScrappyCvc:

    def iniciar(self):
        self.raspagem_de_dados()

    def raspagem_de_dados(self):
        self.driver = webdriver.Chrome('chromedriver', options=chrome_options)
        self.link = f'https://www.cvc.com.br/hotel/search?CheckIn={checkin}&CheckOut={checkout}&Location=%20-%20%20,%20Brasil&ZoneId={id_destino_cvc}&Rooms=1&Adults={pax}&Children=0&ChildAges=;&City=&State=&Country=Brasil&Name='
        self.lista_nome_hoteis = []
        self.lista_preco_hoteis = []
        self.driver.get(self.link)
        sleep(3)
        
        last_height = self.driver.execute_script("return document.body.scrollHeight")
        while True:
            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            sleep(5)
            new_height = self.driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
        lista_length = self.driver.find_elements(By.CLASS_NAME, 'buttonDetailPayments')
        lista_max = len(lista_length)
        
        for p in range(1):
            item = 1
            for i in range(lista_max):
                c = 1
                while c < lista_max:
                    try:
                        lista_nomes = self.driver.find_elements(By.XPATH, f'/html/body/div[1]/div[2]/div/div/div[2]/div/div[{item}]/div/div[2]/div/div[1]/h2')
                        self.lista_nome_hoteis.append(lista_nomes[0].text)
                        sleep(1)
                        lista_precos = self.driver.find_elements(By.XPATH, f'/html/body/div[1]/div[2]/div/div/div[2]/div/div[{item}]/div/div[3]/div/div[1]/div[1]/div[2]')
                        self.lista_preco_hoteis.append(lista_precos[0].text)          
                        sleep(1)
                        item += 1
                    except:
                        c += 1
                        item += 1       
        
        print(f'\u001b[32m{"Resultados:"}\u001b[0m')
        print(self.lista_nome_hoteis)
        print(self.lista_preco_hoteis)
        
        for nome in self.lista_nome_hoteis:
            nome_hoteis_cvc.append(nome)
        for preco in self.lista_preco_hoteis:
            preco_hoteis_cvc.append(preco)
            
start = ScrappyCvc()
start.iniciar()
# Out:
# Resultados:
# ['Barra Norte Hotel', 'Brasil Express Hotel', 'Hotel Vieiras', 'Gravatá Praia Hotel', 'Ibis Budget Navegantes Itajaí', 'Tri Hotel Balneário Camboriú', 'Hotel Vitória - Itajai', 'Hotel Italia Balneario Camboriu', 'Ibis Navegantes Itajaí', 'Itajaí Express Residence', 'Pousada Cores - Navegantes', 'Hotel Marjaí', 'Hotel Itajaí Tur', 'Centromar Hotel', 'Sandri City Hotel', 'Hotel Estação 101 - Itajaí', 'Hotel Geranium', 'Hotel Bella Camboriú', 'Hotel Estação 101 Localizado Em Itajaí', 'Hotel Marambaia Cabeçudas', 'Brasil Express Hotel', 'Sandri Palace Hotel', 'Hotel Praiamar Balneario Camboriu', 'Mercure Itajai Navegantes', 'Atoba Praia Hotel', 'San Marino Cassino Hotel', 'Hm Hotel', 'Flat Concept', 'Marambaia Hotel E Convenções', 'Hotel Itália', 'Novotel Itajaí', 'Hotel Sibara Flat E Convencoes', 'Hotel Sibara Flat E Convenções', 'Hotel D Sintra', 'Hotel Blumenhof Balneario Camboriu', 'Hotel Rieger', 'Hotel Pires', 'Hotel Bhally', 'Hotel Ryan', 'Atobá Praia Hotel', 'Hotel Plaza Camboriu', 'Hamburgo Palace Hotel', 'Styles Balneário Camboriú Hotel', 'Brut By Slaviero Hotéis', 'Hotel Plaza Camboriu', 'Hm Hotel', 'Sofistic Hotel Localizado Em Itapema', 'Mercure Camboriú', 'Itapema Beach Resorts By Nobile']
# ['144', '144', '151', '154', '155', '172', '175', '177', '180', '181', '183', '185', '185', '192', '202', '205', '208', '212', '214', '223', '224', '225', '233', '244', '247', '247', '259', '268', '273', '281', '285', '290', '290', '291', '300', '306', '313', '316', '352', '356', '361', '373', '384', '396', '408', '453', '485', '501', '1081']

# %%
# Lista nome hotéis

print(nome_hoteis_cvc)
# Out:
# ['Barra Norte Hotel', 'Brasil Express Hotel', 'Hotel Vieiras', 'Gravatá Praia Hotel', 'Ibis Budget Navegantes Itajaí', 'Tri Hotel Balneário Camboriú', 'Hotel Vitória - Itajai', 'Hotel Italia Balneario Camboriu', 'Ibis Navegantes Itajaí', 'Itajaí Express Residence', 'Pousada Cores - Navegantes', 'Hotel Marjaí', 'Hotel Itajaí Tur', 'Centromar Hotel', 'Sandri City Hotel', 'Hotel Estação 101 - Itajaí', 'Hotel Geranium', 'Hotel Bella Camboriú', 'Hotel Estação 101 Localizado Em Itajaí', 'Hotel Marambaia Cabeçudas', 'Brasil Express Hotel', 'Sandri Palace Hotel', 'Hotel Praiamar Balneario Camboriu', 'Mercure Itajai Navegantes', 'Atoba Praia Hotel', 'San Marino Cassino Hotel', 'Hm Hotel', 'Flat Concept', 'Marambaia Hotel E Convenções', 'Hotel Itália', 'Novotel Itajaí', 'Hotel Sibara Flat E Convencoes', 'Hotel Sibara Flat E Convenções', 'Hotel D Sintra', 'Hotel Blumenhof Balneario Camboriu', 'Hotel Rieger', 'Hotel Pires', 'Hotel Bhally', 'Hotel Ryan', 'Atobá Praia Hotel', 'Hotel Plaza Camboriu', 'Hamburgo Palace Hotel', 'Styles Balneário Camboriú Hotel', 'Brut By Slaviero Hotéis', 'Hotel Plaza Camboriu', 'Hm Hotel', 'Sofistic Hotel Localizado Em Itapema', 'Mercure Camboriú', 'Itapema Beach Resorts By Nobile']

# %%
# Lista preço hotéis

print(preco_hoteis_cvc)
# Out:
# ['144', '144', '151', '154', '155', '172', '175', '177', '180', '181', '183', '185', '185', '192', '202', '205', '208', '212', '214', '223', '224', '225', '233', '244', '247', '247', '259', '268', '273', '281', '285', '290', '290', '291', '300', '306', '313', '316', '352', '356', '361', '373', '384', '396', '408', '453', '485', '501', '1081']

# %%
# Tratamento formato

preco_hoteis_cvc_num = pd.to_numeric(preco_hoteis_cvc, errors='coerce')
print(preco_hoteis_cvc_num)
# Out:
# [ 144  144  151  154  155  172  175  177  180  181  183  185  185  192
#   202  205  208  212  214  223  224  225  233  244  247  247  259  268
#   273  281  285  290  290  291  300  306  313  316  352  356  361  373
#   384  396  408  453  485  501 1081]

# %%
# Calcula o valor total da estadia pelo nº de noites

from datetime import datetime

preco_hoteis_cvc_rns = []

d2 = datetime.strptime(checkout, '%Y-%m-%d')
d1 = datetime.strptime(checkin, '%Y-%m-%d')
n_diarias = abs((d2 - d1).days)

for el in preco_hoteis_cvc_num:
  preco_total = el * n_diarias
  preco_hoteis_cvc_rns.append(preco_total)

print(preco_hoteis_cvc_rns)
# Out:
# [288, 288, 302, 308, 310, 344, 350, 354, 360, 362, 366, 370, 370, 384, 404, 410, 416, 424, 428, 446, 448, 450, 466, 488, 494, 494, 518, 536, 546, 562, 570, 580, 580, 582, 600, 612, 626, 632, 704, 712, 722, 746, 768, 792, 816, 906, 970, 1002, 2162]

# %%
# Mesclagem nomes e preços em dicionário

data_hoteis_cvc = []
for el in zip(nome_hoteis_cvc, preco_hoteis_cvc_rns):
  data_hoteis_cvc.append(el)
data_hoteis_cvc_dict = dict(data_hoteis_cvc)
print(data_hoteis_cvc_dict)
# Out:
# {'Barra Norte Hotel': 288, 'Brasil Express Hotel': 448, 'Hotel Vieiras': 302, 'Gravatá Praia Hotel': 308, 'Ibis Budget Navegantes Itajaí': 310, 'Tri Hotel Balneário Camboriú': 344, 'Hotel Vitória - Itajai': 350, 'Hotel Italia Balneario Camboriu': 354, 'Ibis Navegantes Itajaí': 360, 'Itajaí Express Residence': 362, 'Pousada Cores - Navegantes': 366, 'Hotel Marjaí': 370, 'Hotel Itajaí Tur': 370, 'Centromar Hotel': 384, 'Sandri City Hotel': 404, 'Hotel Estação 101 - Itajaí': 410, 'Hotel Geranium': 416, 'Hotel Bella Camboriú': 424, 'Hotel Estação 101 Localizado Em Itajaí': 428, 'Hotel Marambaia Cabeçudas': 446, 'Sandri Palace Hotel': 450, 'Hotel Praiamar Balneario Camboriu': 466, 'Mercure Itajai Navegantes': 488, 'Atoba Praia Hotel': 494, 'San Marino Cassino Hotel': 494, 'Hm Hotel': 906, 'Flat Concept': 536, 'Marambaia Hotel E Convenções': 546, 'Hotel Itália': 562, 'Novotel Itajaí': 570, 'Hotel Sibara Flat E Convencoes': 580, 'Hotel Sibara Flat E Convenções': 580, 'Hotel D Sintra': 582, 'Hotel Blumenhof Balneario Camboriu': 600, 'Hotel Rieger': 612, 'Hotel Pires': 626, 'Hotel Bhally': 632, 'Hotel Ryan': 704, 'Atobá Praia Hotel': 712, 'Hotel Plaza Camboriu': 816, 'Hamburgo Palace Hotel': 746, 'Styles Balneário Camboriú Hotel': 768, 'Brut By Slaviero Hotéis': 792, 'Sofistic Hotel Localizado Em Itapema': 970, 'Mercure Camboriú': 1002, 'Itapema Beach Resorts By Nobile': 2162}

# %%
# Conversão dicionário para dataframe

df_data_hoteis_cvc = pd.DataFrame(list(data_hoteis_cvc_dict.items()),
                   columns=['Nome', 'Preço CVC'])
display(df_data_hoteis_cvc)
# Out:
#                                       Nome  Preço CVC
# 0                        Barra Norte Hotel        288
# 1                     Brasil Express Hotel        448
# 2                            Hotel Vieiras        302
# 3                      Gravatá Praia Hotel        308
# 4            Ibis Budget Navegantes Itajaí        310
# 5             Tri Hotel Balneário Camboriú        344
# 6                   Hotel Vitória - Itajai        350
# 7          Hotel Italia Balneario Camboriu        354
# 8                   Ibis Navegantes Itajaí        360
# 9                 Itajaí Express Residence        362
# 10              Pousada Cores - Navegantes        366
# 11                            Hotel Marjaí        370
# 12                        Hotel Itajaí Tur        370
# 13                         Centromar Hotel        384
# 14                       Sandri City Hotel        404
# 15              Hotel Estação 101 - Itajaí        410
# 16                          Hotel Geranium        416
# 17                    Hotel Bella Camboriú        424
# 18  Hotel Estação 101 Localizado Em Itajaí        428
# 19               Hotel Marambaia Cabeçudas        446
# 20                     Sandri Palace Hotel        450
# 21       Hotel Praiamar Balneario Camboriu        466
# 22               Mercure Itajai Navegantes        488
# 23                       Atoba Praia Hotel        494
# 24                San Marino Cassino Hotel        494
# 25                                Hm Hotel        906
# 26                            Flat Concept        536
# 27            Marambaia Hotel E Convenções        546
# 28                            Hotel Itália        562
# 29                          Novotel Itajaí        570
# 30          Hotel Sibara Flat E Convencoes        580
# 31          Hotel Sibara Flat E Convenções        580
# 32                          Hotel D Sintra        582
# 33      Hotel Blumenhof Balneario Camboriu        600
# 34                            Hotel Rieger        612
# 35                             Hotel Pires        626
# 36                            Hotel Bhally        632
# 37                              Hotel Ryan        704
# 38                       Atobá Praia Hotel        712
# 39                    Hotel Plaza Camboriu        816
# 40                   Hamburgo Palace Hotel        746
# 41         Styles Balneário Camboriú Hotel        768
# 42                 Brut By Slaviero Hotéis        792
# 43    Sofistic Hotel Localizado Em Itapema        970
# 44                        Mercure Camboriú       1002
# 45         Itapema Beach Resorts By Nobile       2162

# %%
# Scrape Decolar

nome_hoteis_desp = []
preco_hoteis_desp = []

class ScrappyDesp:

    def iniciar(self):
        self.raspagem_de_dados()

    def raspagem_de_dados(self):
        page = 1
        self.driver = webdriver.Chrome(options=chrome_options)
        self.link = f'https://www.decolar.com/accommodations/results/CIT_{id_destino_decolar}/{checkin}/{checkout}/{pax}?from=SB2&facet=city&searchId=2c403941-a9b6-457f-a17e-5f3131886e89&page={page}'
        self.lista_nome_hoteis = []
        self.lista_preco_hoteis = []
        self.driver.get(self.link)
        self.driver.find_element(By.XPATH, '//*[@id="lgpd-banner"]/div/a[2]').click()
        sleep(3)

        for p in range(20): # Passar como parâmetro nº de páginas a percorrer. Nº > total, percorre todas.
            item = 1
            lista_length = self.driver.find_elements(By.CLASS_NAME, 'accommodation-name')
            lista_max = len(lista_length)
            for i in range(lista_max):
                c = 1
                while c < lista_max:
                    try:
                        lista_nomes = self.driver.find_elements(By.XPATH,
                            f'/html/body/aloha-app-root/aloha-results/div/div/div/div/div[2]/aloha-list-view-container/div[2]/div[{item}]/aloha-cluster-container/div/div/div[1]/div/div[2]/div/aloha-cluster-accommodation-info-container/div[1]/span')
                        self.lista_nome_hoteis.append(lista_nomes[0].text)
                        sleep(1)
                        lista_precos = self.driver.find_elements(By.XPATH,
                            f'/html/body/aloha-app-root/aloha-results/div/div/div/div/div[2]/aloha-list-view-container/div[2]/div[{item}]/aloha-cluster-container/div/div/div[2]/aloha-cluster-pricebox-container/div/div[2]/div[1]/aloha-price-container/aloha-summary-price/div/span[2]')
                        self.lista_preco_hoteis.append(lista_precos[0].text)          
                        sleep(1)
                        item += 1
                    except:
                        item += 1
                        c += 1                        
            try:
                page += 1
                self.driver.get(f'https://www.decolar.com/accommodations/results/CIT_{id_destino_decolar}/{checkin}/{checkout}/{pax}?from=SB2&facet=city&searchId=2c403941-a9b6-457f-a17e-5f3131886e89&page={page}')
                print(f'\u001b[32m{"Navegando para a próxima página"}\u001b[0m')
                sleep(5)
            except:
                self.driver.quit()
        
        print(f'\u001b[32m{"Resultados:"}\u001b[0m')
        print(self.lista_nome_hoteis)
        print(self.lista_preco_hoteis)

        for nome in self.lista_nome_hoteis:
            nome_hoteis_desp.append(nome)
        for preco in self.lista_preco_hoteis:
            preco_hoteis_desp.append(preco)

start = ScrappyDesp()
start.iniciar()
# Out:
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Resultados:
# ['Hotel Ryan', 'Hotel Itália', 'Hotel Pires', 'Hotel Marimar The Place', 'Hotel Sibara Flat & Convenções', 'Hotel Plaza Camboriú', 'Marambaia Hotel e Convenções', 'Hotel Palmas Executivo', 'Hotel dos Açores', 'Hotel Miramar', 'Reserva Praia Hotel', 'Atobá Praia Hotel', 'Brut by Slaviero Hotéis', 'Hotel Vieiras', 'Mercure Camboriu Internacional', 'Tropikalya Gold Hotel', 'Camboriú Praia Hotel', 'Hotel Bella Camboriú', 'Slim Balneário Camboriú by Slaviero Hotéis', 'Santa Inn Hotel', 'Costa Sul Beach Hotel', 'Hotel Melo', 'Hamburgo Palace Hotel', 'Hotel Tropikalya Prime', 'Hotel Geranium', 'Hotel Praiamar', 'Felissimo Exclusive Hotel', 'Hotel Torresol', 'HOTEL SAN REMO INTERNACIONAL', 'Pousada Ponta do Lobo', 'Rezende Suítes Hotel', 'Hotel Blumenhof Balneário Camboriú', 'H Hotel', 'Pousada Villa Atlântica', 'Mar Hotel', 'Hotel Shallom', 'Brasil Express Hotel', 'Hotel Torre Sol', 'Rieger Balneario Camboriu', 'Apartamento Edifício República Argentina - Balneário Camboriú', 'Hotel Visual', 'Flat Concept', 'Rizzu Marina Hotel', 'Pousada do Bosque Di Sica', 'Hotel Ita Lia', 'Cabanas Hostel', 'BC Paradise Hostel']
# ['580', '550', '432', '622', '588', '746', '530', '454', '402', '704', '976', '562', '646', '342', '1.160', '444', '448', '454', '360', '1.270', '582', '530', '544', '420', '444', '348', '2.292', '396', '302', '540', '314', '452', '446', '398', '274', '324', '354', '424', '728', '838', '390', '704', '1.098', '390', '600', '590', '242']

# %%
# Lista nome hotéis

print(nome_hoteis_desp)
# Out:
# ['Hotel Ryan', 'Hotel Itália', 'Hotel Pires', 'Hotel Marimar The Place', 'Hotel Sibara Flat & Convenções', 'Hotel Plaza Camboriú', 'Marambaia Hotel e Convenções', 'Hotel Palmas Executivo', 'Hotel dos Açores', 'Hotel Miramar', 'Reserva Praia Hotel', 'Atobá Praia Hotel', 'Brut by Slaviero Hotéis', 'Hotel Vieiras', 'Mercure Camboriu Internacional', 'Tropikalya Gold Hotel', 'Camboriú Praia Hotel', 'Hotel Bella Camboriú', 'Slim Balneário Camboriú by Slaviero Hotéis', 'Santa Inn Hotel', 'Costa Sul Beach Hotel', 'Hotel Melo', 'Hamburgo Palace Hotel', 'Hotel Tropikalya Prime', 'Hotel Geranium', 'Hotel Praiamar', 'Felissimo Exclusive Hotel', 'Hotel Torresol', 'HOTEL SAN REMO INTERNACIONAL', 'Pousada Ponta do Lobo', 'Rezende Suítes Hotel', 'Hotel Blumenhof Balneário Camboriú', 'H Hotel', 'Pousada Villa Atlântica', 'Mar Hotel', 'Hotel Shallom', 'Brasil Express Hotel', 'Hotel Torre Sol', 'Rieger Balneario Camboriu', 'Apartamento Edifício República Argentina - Balneário Camboriú', 'Hotel Visual', 'Flat Concept', 'Rizzu Marina Hotel', 'Pousada do Bosque Di Sica', 'Hotel Ita Lia', 'Cabanas Hostel', 'BC Paradise Hostel']

# %%
# Lista preço hotéis

print(preco_hoteis_desp)
# Out:
# ['580', '550', '432', '622', '588', '746', '530', '454', '402', '704', '976', '562', '646', '342', '1.160', '444', '448', '454', '360', '1.270', '582', '530', '544', '420', '444', '348', '2.292', '396', '302', '540', '314', '452', '446', '398', '274', '324', '354', '424', '728', '838', '390', '704', '1.098', '390', '600', '590', '242']

# %%
# Tratamento formato

preco_hoteis_desp_nofloat = []
for x in preco_hoteis_desp:
    item = x
    for y in ["."]:
        item = item.replace(y, "")
    preco_hoteis_desp_nofloat.append(item)
print(preco_hoteis_desp_nofloat)
# Out:
# ['580', '550', '432', '622', '588', '746', '530', '454', '402', '704', '976', '562', '646', '342', '1160', '444', '448', '454', '360', '1270', '582', '530', '544', '420', '444', '348', '2292', '396', '302', '540', '314', '452', '446', '398', '274', '324', '354', '424', '728', '838', '390', '704', '1098', '390', '600', '590', '242']

# %%
# Tratamento formato

preco_hoteis_desp_num = pd.to_numeric(preco_hoteis_desp_nofloat, errors='coerce')
print(preco_hoteis_desp_num)
# Out:
# [ 580  550  432  622  588  746  530  454  402  704  976  562  646  342
#  1160  444  448  454  360 1270  582  530  544  420  444  348 2292  396
#   302  540  314  452  446  398  274  324  354  424  728  838  390  704
#  1098  390  600  590  242]

# %%
# Mesclagem nomes e preços em dicionário

data_hoteis_desp = []
for el in zip(nome_hoteis_desp, preco_hoteis_desp_num):
    data_hoteis_desp.append(el)
data_hoteis_desp_dict = dict(data_hoteis_desp)
print(data_hoteis_desp_dict)
# Out:
# {'Hotel Ryan': 580, 'Hotel Itália': 550, 'Hotel Pires': 432, 'Hotel Marimar The Place': 622, 'Hotel Sibara Flat & Convenções': 588, 'Hotel Plaza Camboriú': 746, 'Marambaia Hotel e Convenções': 530, 'Hotel Palmas Executivo': 454, 'Hotel dos Açores': 402, 'Hotel Miramar': 704, 'Reserva Praia Hotel': 976, 'Atobá Praia Hotel': 562, 'Brut by Slaviero Hotéis': 646, 'Hotel Vieiras': 342, 'Mercure Camboriu Internacional': 1160, 'Tropikalya Gold Hotel': 444, 'Camboriú Praia Hotel': 448, 'Hotel Bella Camboriú': 454, 'Slim Balneário Camboriú by Slaviero Hotéis': 360, 'Santa Inn Hotel': 1270, 'Costa Sul Beach Hotel': 582, 'Hotel Melo': 530, 'Hamburgo Palace Hotel': 544, 'Hotel Tropikalya Prime': 420, 'Hotel Geranium': 444, 'Hotel Praiamar': 348, 'Felissimo Exclusive Hotel': 2292, 'Hotel Torresol': 396, 'HOTEL SAN REMO INTERNACIONAL': 302, 'Pousada Ponta do Lobo': 540, 'Rezende Suítes Hotel': 314, 'Hotel Blumenhof Balneário Camboriú': 452, 'H Hotel': 446, 'Pousada Villa Atlântica': 398, 'Mar Hotel': 274, 'Hotel Shallom': 324, 'Brasil Express Hotel': 354, 'Hotel Torre Sol': 424, 'Rieger Balneario Camboriu': 728, 'Apartamento Edifício República Argentina - Balneário Camboriú': 838, 'Hotel Visual': 390, 'Flat Concept': 704, 'Rizzu Marina Hotel': 1098, 'Pousada do Bosque Di Sica': 390, 'Hotel Ita Lia': 600, 'Cabanas Hostel': 590, 'BC Paradise Hostel': 242}

# %%
# Conversão dicionário para dataframe

df_data_hoteis_desp = pd.DataFrame(list(data_hoteis_desp_dict.items()),
                   columns=['Nome', 'Preço Decolar'])
display(df_data_hoteis_desp)
# Out:
#                                                  Nome  Preço Decolar
# 0                                          Hotel Ryan            580
# 1                                        Hotel Itália            550
# 2                                         Hotel Pires            432
# 3                             Hotel Marimar The Place            622
# 4                      Hotel Sibara Flat & Convenções            588
# 5                                Hotel Plaza Camboriú            746
# 6                        Marambaia Hotel e Convenções            530
# 7                              Hotel Palmas Executivo            454
# 8                                    Hotel dos Açores            402
# 9                                       Hotel Miramar            704
# 10                                Reserva Praia Hotel            976
# 11                                  Atobá Praia Hotel            562
# 12                            Brut by Slaviero Hotéis            646
# 13                                      Hotel Vieiras            342
# 14                     Mercure Camboriu Internacional           1160
# 15                              Tropikalya Gold Hotel            444
# 16                               Camboriú Praia Hotel            448
# 17                               Hotel Bella Camboriú            454
# 18         Slim Balneário Camboriú by Slaviero Hotéis            360
# 19                                    Santa Inn Hotel           1270
# 20                              Costa Sul Beach Hotel            582
# 21                                         Hotel Melo            530
# 22                              Hamburgo Palace Hotel            544
# 23                             Hotel Tropikalya Prime            420
# 24                                     Hotel Geranium            444
# 25                                     Hotel Praiamar            348
# 26                          Felissimo Exclusive Hotel           2292
# 27                                     Hotel Torresol            396
# 28                       HOTEL SAN REMO INTERNACIONAL            302
# 29                              Pousada Ponta do Lobo            540
# 30                               Rezende Suítes Hotel            314
# 31                 Hotel Blumenhof Balneário Camboriú            452
# 32                                            H Hotel            446
# 33                            Pousada Villa Atlântica            398
# 34                                          Mar Hotel            274
# 35                                      Hotel Shallom            324
# 36                               Brasil Express Hotel            354
# 37                                    Hotel Torre Sol            424
# 38                          Rieger Balneario Camboriu            728
# 39  Apartamento Edifício República Argentina - Bal...            838
# 40                                       Hotel Visual            390
# 41                                       Flat Concept            704
# 42                                 Rizzu Marina Hotel           1098
# 43                          Pousada do Bosque Di Sica            390
# 44                                      Hotel Ita Lia            600
# 45                                     Cabanas Hostel            590
# 46                                 BC Paradise Hostel            242

# %%
# Merge data

data_merge = pd.merge(df_data_hoteis_cvc, df_data_hoteis_desp, on=['Nome'], how='left')
display(data_merge)
# Out:
#                                       Nome  Preço CVC  Preço Decolar
# 0                        Barra Norte Hotel        288            NaN
# 1                     Brasil Express Hotel        448          354.0
# 2                            Hotel Vieiras        302          342.0
# 3                      Gravatá Praia Hotel        308            NaN
# 4            Ibis Budget Navegantes Itajaí        310            NaN
# 5             Tri Hotel Balneário Camboriú        344            NaN
# 6                   Hotel Vitória - Itajai        350            NaN
# 7          Hotel Italia Balneario Camboriu        354            NaN
# 8                   Ibis Navegantes Itajaí        360            NaN
# 9                 Itajaí Express Residence        362            NaN
# 10              Pousada Cores - Navegantes        366            NaN
# 11                            Hotel Marjaí        370            NaN
# 12                        Hotel Itajaí Tur        370            NaN
# 13                         Centromar Hotel        384            NaN
# 14                       Sandri City Hotel        404            NaN
# 15              Hotel Estação 101 - Itajaí        410            NaN
# 16                          Hotel Geranium        416          444.0
# 17                    Hotel Bella Camboriú        424          454.0
# 18  Hotel Estação 101 Localizado Em Itajaí        428            NaN
# 19               Hotel Marambaia Cabeçudas        446            NaN
# 20                     Sandri Palace Hotel        450            NaN
# 21       Hotel Praiamar Balneario Camboriu        466            NaN
# 22               Mercure Itajai Navegantes        488            NaN
# 23                       Atoba Praia Hotel        494            NaN
# 24                San Marino Cassino Hotel        494            NaN
# 25                                Hm Hotel        906            NaN
# 26                            Flat Concept        536          704.0
# 27            Marambaia Hotel E Convenções        546            NaN
# 28                            Hotel Itália        562          550.0
# 29                          Novotel Itajaí        570            NaN
# 30          Hotel Sibara Flat E Convencoes        580            NaN
# 31          Hotel Sibara Flat E Convenções        580            NaN
# 32                          Hotel D Sintra        582            NaN
# 33      Hotel Blumenhof Balneario Camboriu        600            NaN
# 34                            Hotel Rieger        612            NaN
# 35                             Hotel Pires        626          432.0
# 36                            Hotel Bhally        632            NaN
# 37                              Hotel Ryan        704          580.0
# 38                       Atobá Praia Hotel        712          562.0
# 39                    Hotel Plaza Camboriu        816            NaN
# 40                   Hamburgo Palace Hotel        746          544.0
# 41         Styles Balneário Camboriú Hotel        768            NaN
# 42                 Brut By Slaviero Hotéis        792            NaN
# 43    Sofistic Hotel Localizado Em Itapema        970            NaN
# 44                        Mercure Camboriú       1002            NaN
# 45         Itapema Beach Resorts By Nobile       2162            NaN

# %%
# Limpeza NaN

data_merge_notna = data_merge.dropna()
display(data_merge_notna)
# Out:
#                      Nome  Preço CVC  Preço Decolar
# 1    Brasil Express Hotel        448          354.0
# 2           Hotel Vieiras        302          342.0
# 16         Hotel Geranium        416          444.0
# 17   Hotel Bella Camboriú        424          454.0
# 26           Flat Concept        536          704.0
# 28           Hotel Itália        562          550.0
# 35            Hotel Pires        626          432.0
# 37             Hotel Ryan        704          580.0
# 38      Atobá Praia Hotel        712          562.0
# 40  Hamburgo Palace Hotel        746          544.0

# %%
# Comparação de preços

df_rate_comparison = data_merge_notna
display(df_rate_comparison)
# Out:
#                      Nome  Preço CVC  Preço Decolar
# 1    Brasil Express Hotel        448          354.0
# 2           Hotel Vieiras        302          342.0
# 16         Hotel Geranium        416          444.0
# 17   Hotel Bella Camboriú        424          454.0
# 26           Flat Concept        536          704.0
# 28           Hotel Itália        562          550.0
# 35            Hotel Pires        626          432.0
# 37             Hotel Ryan        704          580.0
# 38      Atobá Praia Hotel        712          562.0
# 40  Hamburgo Palace Hotel        746          544.0

# %%
df_rate_comparison['% Diferença'] = 0
for el in df_rate_comparison:
    dif = (df_rate_comparison['Preço Decolar'] / df_rate_comparison['Preço CVC'] -1 ) * 100
    df_rate_comparison['% Diferença'] = round(dif, 0)
display(df_rate_comparison)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                      Nome  Preço CVC  Preço Decolar  % Diferença
# 1    Brasil Express Hotel        448          354.0        -21.0
# 2           Hotel Vieiras        302          342.0         13.0
# 16         Hotel Geranium        416          444.0          7.0
# 17   Hotel Bella Camboriú        424          454.0          7.0
# 26           Flat Concept        536          704.0         31.0
# 28           Hotel Itália        562          550.0         -2.0
# 35            Hotel Pires        626          432.0        -31.0
# 37             Hotel Ryan        704          580.0        -18.0
# 38      Atobá Praia Hotel        712          562.0        -21.0
# 40  Hamburgo Palace Hotel        746          544.0        -27.0

# %%
# Highlight adversas

def highlight_adversas(s):
    color_red = 'red'
    color_yellow = 'yellow'
    color_green = 'green'
    if s >= 15:
      return 'background-color: %s' % color_red
    elif s < 15 and s > 0:
      return 'background-color: %s' % color_yellow
    elif s <= 0:
      return 'background-color: %s' % color_green

reporte_adversas = df_rate_comparison.style.applymap(highlight_adversas, subset=pd.IndexSlice[:, ['% Diferença']])

# %%
# Conversão dataframe para XLSX

writer = pd.ExcelWriter('Reporte Paridade CVC - {}.xlsx'.format(nome_destino))
reporte_adversas.to_excel(writer, f'IN_{checkin} - OUT_{checkout}', index=False)
writer.save()

# %%
# Download XLSX

from google.colab import files
files.download('Reporte Paridade CVC - {}.xlsx'.format(nome_destino))

# %%
# % adversas

medicoes = 0
for m in df_rate_comparison['% Diferença']:
  medicoes += 1

adversas = 0
for a in df_rate_comparison['% Diferença']:
  if a > 0:
    adversas += 1

percent_adversas = (adversas / medicoes) * 100

# %%
import email, smtplib, ssl
from email import encoders
from email.mime.base import MIMEBase
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

# %%
# Dispara e-mail

anexo = "Reporte Paridade CVC - {}.xlsx".format(nome_destino)

def sendMail():
    try:
        subject = "Reporte Paridade CVC - {}".format(nome_destino)
        body = f"Destino: {nome_destino}\n\nCheck-in: {checkin}\nCheck-out: {checkout}\nLOS: {n_diarias}\nPax: {pax}\n\nPercentual adversas: {percent_adversas:.2f}%"
        sender_email = ""
        password = ""
        receiver_email = ""

        message = MIMEMultipart()

        message["From"] = sender_email
        message["To"] = receiver_email
        message["Subject"] = subject

        message.attach(MIMEText(body, "plain"))

        filename = anexo

        with open(filename, "rb") as attachment:
            part = MIMEBase("application", "octet-stream")
            part.set_payload(attachment.read())

        encoders.encode_base64(part)

        part.add_header(
            "Content-Disposition",
            f"attachment; filename = {filename}",
        )

        message.attach(part)
        text = message.as_string()

        context = ssl.create_default_context()
        with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
            server.login(sender_email, password)
            server.sendmail(sender_email, receiver_email, text)
        
        print('E-mail enviado com sucesso!')
    except:
        print('Erro ao enviar e-mail')

sendMail()
# Out:
# E-mail enviado com sucesso!
