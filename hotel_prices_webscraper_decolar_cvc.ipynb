# %% [markdown]
# Hotel Prices Webscraper Decolar x CVC

# %%
# !pip install selenium
# !apt-get update 
# !apt install chromium-chromedriver
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (4.0.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.19.0)
# Requirement already satisfied: urllib3[secure]~=1.26 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium) (1.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (2021.5.30)
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (35.0.0)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure]~=1.26->selenium) (2.20)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.12.0)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Ign:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 252 kB in 2s (106 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (95.0.4638.69-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 54 not upgraded.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import *
from time import sleep
import pandas as pd
import os

# %%
# Lista IDs destinos

# ID destinos CVC
  #Aracaju: 8726
  #Arraial d'Ajuda: 35727
  #Balneário Camboriú: 33964
  #Belo Horizonte: 2920
  #Brasília: 1911
  #Búzios: 36132
  #Cabo Frio: 6940
  #Caldas Novas: 2263
  #Campinas: 8983
  #Campos do Jordão: 8986
  #Canela: 7538
  #Curitiba: 6162
  #Florianópolis: 8400
  #Fortaleza: 1463
  #Foz do Iguaçú: 6236
  #Gramado: 7752
  #Ilhabela: 9172
  #Ilhéus: 747
  #João Pessoa: 5104
  #Maceió: 185
  #Morro de São Paulo: 938
  #Natal: 34584
  #Porto Alegre: 8002
  #Porto de Galinhas: 5648
  #Porto Seguro: 1032
  #Praia de Pipa: 7299
  #Recife: 5541
  #Rio de Janeiro: 7110
  #Salvador: 1076
  #São Paulo: 9626

# ID destinos Decolar
  #Aracaju: 180
  #Arraial d'Ajuda: 339
  #Balneário Camboriú: 192594
  #Belo Horizonte: 701
  #Brasília: 926
  #Búzios: 1077
  #Cabo Frio: 1227
  #Caldas Novas: 1364
  #Campinas: 1467
  #Campos do Jordão: 6116
  #Canela: 6064
  #Curitiba: 1595
  #Florianópolis: 2261
  #Fortaleza: 2302
  #Foz do Iguaçu: 3072
  #Gramado: 2611
  #Ilhabela: 3027
  #Ilhéus: 3158
  #João Pessoa: 3399
  #Maceió: 4430
  #Morro de São Paulo: 4678
  #Natal: 4971
  #Porto Alegre: 5822
  #Porto de Galinhas: 5648
  #Porto Seguro: 881
  #Praia de Pipa: 5875
  #Recife: 6322
  #Rio de Janeiro: 6381
  #Salvador: 7018
  #São Paulo: 6574

# %%
# Parâmetros

id_destino_cvc = '6162'
id_destino_decolar = '1595'
checkin = '2021-11-28' # Formato AAAA-MM-DD
checkout = '2021-11-30' # Formato AAAA-MM-DD
pax = '2' # Número de hóspedes (adultos)

# %%
# Definições Chromedriver

chrome_options = webdriver.ChromeOptions()
chrome_options.add_experimental_option('excludeSwitches', ['enable-logging'])
chrome_options.add_argument('--lang=pr-BR')
chrome_options.add_argument('--disable-notifications')
chrome_options.add_argument('--headless')
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# %%
# Scrape CVC

nome_hoteis_cvc = []
preco_hoteis_cvc = []

class ScrappyCvc:

    def iniciar(self):
        self.raspagem_de_dados()

    def raspagem_de_dados(self):
        self.driver = webdriver.Chrome('chromedriver', options=chrome_options)
        self.link = f'https://www.cvc.com.br/hotel/search?CheckIn={checkin}&CheckOut={checkout}&Location=%20-%20%20,%20Brasil&ZoneId={id_destino_cvc}&Rooms=1&Adults={pax}&Children=0&ChildAges=;&City=&State=&Country=Brasil&Name='
        self.lista_nome_hoteis = []
        self.lista_preco_hoteis = []
        self.driver.get(self.link)
        sleep(2)
        
        last_height = self.driver.execute_script("return document.body.scrollHeight")
        while True:
            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            sleep(2)
            new_height = self.driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height
        lista_length = self.driver.find_elements(By.CLASS_NAME, 'buttonDetailPayments')
        lista_max = len(lista_length)
        
        for p in range(1):
            item = 1
            for i in range(lista_max):
                c = 1
                while c < lista_max:
                    try:
                        lista_nomes = self.driver.find_elements(By.XPATH, f'/html/body/div[1]/div[2]/div/div/div[2]/div/div[{item}]/div/div[2]/div/div[1]/h2')
                        self.lista_nome_hoteis.append(lista_nomes[0].text)
                        sleep(1)
                        lista_precos = self.driver.find_elements(By.XPATH, f'/html/body/div[1]/div[2]/div/div/div[2]/div/div[{item}]/div/div[3]/div/div[1]/div[1]/div[2]')
                        self.lista_preco_hoteis.append(lista_precos[0].text)          
                        sleep(1)
                        item += 1
                    except:
                        c += 1
                        item += 1       
        
        print(f'\u001b[32m{"Resultados:"}\u001b[0m')
        print(self.lista_nome_hoteis)
        print(self.lista_preco_hoteis)
        
        for nome in self.lista_nome_hoteis:
            nome_hoteis_cvc.append(nome)
        for preco in self.lista_preco_hoteis:
            preco_hoteis_cvc.append(preco)
            
start = ScrappyCvc()
start.iniciar()
# Out:
# Resultados:
# ['Hotel Tibagi', 'Hotel Granville', 'Hotel Pinheirinho', 'Golden Park Curitiba', 'Master Express Curitiba', 'Caravelle Palace Hotel', 'Bristol Portal Do Iguaçu', 'Ibis Budget Curitiba Centro', 'Nacional Inn Curitiba Estação', 'Ibis Curitiba Batel', 'Ibis Styles Curitiba Batel', 'Nacional Inn Curitiba Torres', 'Roochelle Hotel', 'Ibis Curitiba Aeroporto', 'Dan Inn Curitiba', 'Bristol Upper', 'Go Inn Curitiba', 'San Juan Executive Curitiba', 'Mercure Curitiba Aeroporto', 'Ibis Styles Curitiba Centro Cívico', 'Bristol Metropolitan', 'Alta Reggia Plaza Hotel', 'Hotel Aladdin', 'Blue Tree Towers Saint Michel - Curitiba', 'Victoria Villa Curitiba', 'Saint Emilion Hotel', 'Ibis Styles Curitiba Santa Felicidade', 'Slim Curitiba Av. Das Torres', 'Mabu Curitiba Business', 'Hotel Moov Curitiba', 'Bristol Centro Cívico', 'Hotel Intercity Curitiba Batel', 'Trevi Hotel & Business', 'Lira Hotel', 'Deville Curitiba Batel', 'Ibis Curitiba Shopping', 'Slim Curitiba Alto Da Xv', 'Batel - Rio Hotel By Bourbon Curitiba', 'Hotel Intercity Curitiba – Centro Cívico', 'San Juan Royal Curitiba', 'Hotel Del Rey - Curitiba', 'Rockefeller By Slaviero Hotéis', 'Hotel Del Rey Curitiba', 'San Juan Johnscher Curitiba', 'Hotel Sol', 'Mercure Curitiba Sete De Setembro', 'Slaviero Essential Curitiba Shopping', 'Slaviero Essential Curitiba Batel', 'Ibis Styles Curitiba Aeroporto', 'Astron Suítes São José Dos Pinhais', 'Mercure Curitiba Golden', 'Lizon Curitiba Hotel', 'Bourbon Curitiba Convention Hotel', 'Slaviero Essential Curitiba Centro', 'Pestana Curitiba Hotel', 'Hotel Confiance Barigui', 'Bristol Brasil 500', 'Transamerica Prime Batel Curitiba', 'Grand Mercure Curitiba Rayon', 'Hotel Flat Petras', 'Hotel Centro Europeu', 'Mercure Curitiba Batel', 'Full Jazz By Slaviero Hotéis', 'Nh Curitiba The Five', 'Quality Hotel Curitiba', 'Novotel Curitiba Batel', 'Blue Tree Towers Batel Curitiba', 'Radisson Hotel Curitiba', 'Nomaa Hotel']
# ['111', '122', '137', '139', '158', '159', '160', '161', '162', '166', '173', '176', '179', '188', '192', '193', '193', '193', '194', '194', '198', '202', '203', '209', '213', '215', '216', '216', '217', '223', '225', '225', '227', '228', '230', '230', '234', '235', '236', '239', '240', '244', '245', '246', '246', '248', '251', '252', '256', '257', '259', '268', '270', '274', '278', '282', '299', '305', '320', '324', '327', '338', '342', '351', '352', '363', '389', '394', '629']

# %%
# Lista nome hotéis

print(nome_hoteis_cvc)
# Out:
# ['Hotel Tibagi', 'Hotel Granville', 'Hotel Pinheirinho', 'Golden Park Curitiba', 'Master Express Curitiba', 'Caravelle Palace Hotel', 'Bristol Portal Do Iguaçu', 'Ibis Budget Curitiba Centro', 'Nacional Inn Curitiba Estação', 'Ibis Curitiba Batel', 'Ibis Styles Curitiba Batel', 'Nacional Inn Curitiba Torres', 'Roochelle Hotel', 'Ibis Curitiba Aeroporto', 'Dan Inn Curitiba', 'Bristol Upper', 'Go Inn Curitiba', 'San Juan Executive Curitiba', 'Mercure Curitiba Aeroporto', 'Ibis Styles Curitiba Centro Cívico', 'Bristol Metropolitan', 'Alta Reggia Plaza Hotel', 'Hotel Aladdin', 'Blue Tree Towers Saint Michel - Curitiba', 'Victoria Villa Curitiba', 'Saint Emilion Hotel', 'Ibis Styles Curitiba Santa Felicidade', 'Slim Curitiba Av. Das Torres', 'Mabu Curitiba Business', 'Hotel Moov Curitiba', 'Bristol Centro Cívico', 'Hotel Intercity Curitiba Batel', 'Trevi Hotel & Business', 'Lira Hotel', 'Deville Curitiba Batel', 'Ibis Curitiba Shopping', 'Slim Curitiba Alto Da Xv', 'Batel - Rio Hotel By Bourbon Curitiba', 'Hotel Intercity Curitiba – Centro Cívico', 'San Juan Royal Curitiba', 'Hotel Del Rey - Curitiba', 'Rockefeller By Slaviero Hotéis', 'Hotel Del Rey Curitiba', 'San Juan Johnscher Curitiba', 'Hotel Sol', 'Mercure Curitiba Sete De Setembro', 'Slaviero Essential Curitiba Shopping', 'Slaviero Essential Curitiba Batel', 'Ibis Styles Curitiba Aeroporto', 'Astron Suítes São José Dos Pinhais', 'Mercure Curitiba Golden', 'Lizon Curitiba Hotel', 'Bourbon Curitiba Convention Hotel', 'Slaviero Essential Curitiba Centro', 'Pestana Curitiba Hotel', 'Hotel Confiance Barigui', 'Bristol Brasil 500', 'Transamerica Prime Batel Curitiba', 'Grand Mercure Curitiba Rayon', 'Hotel Flat Petras', 'Hotel Centro Europeu', 'Mercure Curitiba Batel', 'Full Jazz By Slaviero Hotéis', 'Nh Curitiba The Five', 'Quality Hotel Curitiba', 'Novotel Curitiba Batel', 'Blue Tree Towers Batel Curitiba', 'Radisson Hotel Curitiba', 'Nomaa Hotel']

# %%
# Lista preço hotéis

print(preco_hoteis_cvc)
# Out:
# ['111', '122', '137', '139', '158', '159', '160', '161', '162', '166', '173', '176', '179', '188', '192', '193', '193', '193', '194', '194', '198', '202', '203', '209', '213', '215', '216', '216', '217', '223', '225', '225', '227', '228', '230', '230', '234', '235', '236', '239', '240', '244', '245', '246', '246', '248', '251', '252', '256', '257', '259', '268', '270', '274', '278', '282', '299', '305', '320', '324', '327', '338', '342', '351', '352', '363', '389', '394', '629']

# %%
# Tratamento formato

preco_hoteis_cvc_num = pd.to_numeric(preco_hoteis_cvc, errors='coerce')
print(preco_hoteis_cvc_num)
# Out:
# [111 122 137 139 158 159 160 161 162 166 173 176 179 188 192 193 193 193
#  194 194 198 202 203 209 213 215 216 216 217 223 225 225 227 228 230 230
#  234 235 236 239 240 244 245 246 246 248 251 252 256 257 259 268 270 274
#  278 282 299 305 320 324 327 338 342 351 352 363 389 394 629]

# %%
# Calcula o valor total da estadia pelo nº de noites

from datetime import datetime

preco_hoteis_cvc_rns = []

d2 = datetime.strptime(checkout, '%Y-%m-%d')
d1 = datetime.strptime(checkin, '%Y-%m-%d')
n_diarias = abs((d2 - d1).days)

for el in preco_hoteis_cvc_num:
  preco_total = el * n_diarias
  preco_hoteis_cvc_rns.append(preco_total)

print(preco_hoteis_cvc_rns)
# Out:
# [222, 244, 274, 278, 316, 318, 320, 322, 324, 332, 346, 352, 358, 376, 384, 386, 386, 386, 388, 388, 396, 404, 406, 418, 426, 430, 432, 432, 434, 446, 450, 450, 454, 456, 460, 460, 468, 470, 472, 478, 480, 488, 490, 492, 492, 496, 502, 504, 512, 514, 518, 536, 540, 548, 556, 564, 598, 610, 640, 648, 654, 676, 684, 702, 704, 726, 778, 788, 1258]

# %%
# Mesclagem nomes e preços em dicionário

data_hoteis_cvc = []
for el in zip(nome_hoteis_cvc, preco_hoteis_cvc_rns):
  data_hoteis_cvc.append(el)
data_hoteis_cvc_dict = dict(data_hoteis_cvc)
print(data_hoteis_cvc_dict)
# Out:
# {'Hotel Tibagi': 222, 'Hotel Granville': 244, 'Hotel Pinheirinho': 274, 'Golden Park Curitiba': 278, 'Master Express Curitiba': 316, 'Caravelle Palace Hotel': 318, 'Bristol Portal Do Iguaçu': 320, 'Ibis Budget Curitiba Centro': 322, 'Nacional Inn Curitiba Estação': 324, 'Ibis Curitiba Batel': 332, 'Ibis Styles Curitiba Batel': 346, 'Nacional Inn Curitiba Torres': 352, 'Roochelle Hotel': 358, 'Ibis Curitiba Aeroporto': 376, 'Dan Inn Curitiba': 384, 'Bristol Upper': 386, 'Go Inn Curitiba': 386, 'San Juan Executive Curitiba': 386, 'Mercure Curitiba Aeroporto': 388, 'Ibis Styles Curitiba Centro Cívico': 388, 'Bristol Metropolitan': 396, 'Alta Reggia Plaza Hotel': 404, 'Hotel Aladdin': 406, 'Blue Tree Towers Saint Michel - Curitiba': 418, 'Victoria Villa Curitiba': 426, 'Saint Emilion Hotel': 430, 'Ibis Styles Curitiba Santa Felicidade': 432, 'Slim Curitiba Av. Das Torres': 432, 'Mabu Curitiba Business': 434, 'Hotel Moov Curitiba': 446, 'Bristol Centro Cívico': 450, 'Hotel Intercity Curitiba Batel': 450, 'Trevi Hotel & Business': 454, 'Lira Hotel': 456, 'Deville Curitiba Batel': 460, 'Ibis Curitiba Shopping': 460, 'Slim Curitiba Alto Da Xv': 468, 'Batel - Rio Hotel By Bourbon Curitiba': 470, 'Hotel Intercity Curitiba – Centro Cívico': 472, 'San Juan Royal Curitiba': 478, 'Hotel Del Rey - Curitiba': 480, 'Rockefeller By Slaviero Hotéis': 488, 'Hotel Del Rey Curitiba': 490, 'San Juan Johnscher Curitiba': 492, 'Hotel Sol': 492, 'Mercure Curitiba Sete De Setembro': 496, 'Slaviero Essential Curitiba Shopping': 502, 'Slaviero Essential Curitiba Batel': 504, 'Ibis Styles Curitiba Aeroporto': 512, 'Astron Suítes São José Dos Pinhais': 514, 'Mercure Curitiba Golden': 518, 'Lizon Curitiba Hotel': 536, 'Bourbon Curitiba Convention Hotel': 540, 'Slaviero Essential Curitiba Centro': 548, 'Pestana Curitiba Hotel': 556, 'Hotel Confiance Barigui': 564, 'Bristol Brasil 500': 598, 'Transamerica Prime Batel Curitiba': 610, 'Grand Mercure Curitiba Rayon': 640, 'Hotel Flat Petras': 648, 'Hotel Centro Europeu': 654, 'Mercure Curitiba Batel': 676, 'Full Jazz By Slaviero Hotéis': 684, 'Nh Curitiba The Five': 702, 'Quality Hotel Curitiba': 704, 'Novotel Curitiba Batel': 726, 'Blue Tree Towers Batel Curitiba': 778, 'Radisson Hotel Curitiba': 788, 'Nomaa Hotel': 1258}

# %%
# Conversão dicionário para dataframe

df_data_hoteis_cvc = pd.DataFrame(list(data_hoteis_cvc_dict.items()),
                   columns=['Nome', 'Preço CVC'])
display(df_data_hoteis_cvc)
# Out:
#                                Nome  Preço CVC
# 0                      Hotel Tibagi        222
# 1                   Hotel Granville        244
# 2                 Hotel Pinheirinho        274
# 3              Golden Park Curitiba        278
# 4           Master Express Curitiba        316
# ..                              ...        ...
# 64           Quality Hotel Curitiba        704
# 65           Novotel Curitiba Batel        726
# 66  Blue Tree Towers Batel Curitiba        778
# 67          Radisson Hotel Curitiba        788
# 68                      Nomaa Hotel       1258
#
# [69 rows x 2 columns]

# %%
# Scrape Decolar

nome_hoteis_desp = []
preco_hoteis_desp = []

class ScrappyDesp:

    def iniciar(self):
        self.raspagem_de_dados()

    def raspagem_de_dados(self):
        page = 1
        self.driver = webdriver.Chrome(options=chrome_options)
        self.link = f'https://www.decolar.com/accommodations/results/CIT_{id_destino_decolar}/{checkin}/{checkout}/{pax}?from=SB2&facet=city&searchId=2c403941-a9b6-457f-a17e-5f3131886e89&page={page}'
        self.lista_nome_hoteis = []
        self.lista_preco_hoteis = []
        self.driver.get(self.link)
        self.driver.find_element(By.XPATH, '//*[@id="lgpd-banner"]/div/a[2]').click()
        sleep(2)

        for p in range(20): # Passar como parâmetro nº de páginas a percorrer. Nº > total, percorre todas.
            item = 1
            lista_length = self.driver.find_elements(By.CLASS_NAME, 'accommodation-name')
            lista_max = len(lista_length)
            for i in range(lista_max):
                c = 1
                while c < lista_max:
                    try:
                        lista_nomes = self.driver.find_elements(By.XPATH,
                            f'/html/body/aloha-app-root/aloha-results/div/div/div/div/div[2]/aloha-list-view-container/div[2]/div[{item}]/aloha-cluster-container/div/div/div[1]/div/div[2]/div/aloha-cluster-accommodation-info-container/div[1]/span')
                        self.lista_nome_hoteis.append(lista_nomes[0].text)
                        sleep(1)
                        lista_precos = self.driver.find_elements(By.XPATH,
                            f'/html/body/aloha-app-root/aloha-results/div/div/div/div/div[2]/aloha-list-view-container/div[2]/div[{item}]/aloha-cluster-container/div/div/div[2]/aloha-cluster-pricebox-container/div/div[2]/div[1]/aloha-price-container/aloha-summary-price/div/span[2]')
                        self.lista_preco_hoteis.append(lista_precos[0].text)          
                        sleep(1)
                        item += 1
                    except:
                        item += 1
                        c += 1                        
            try:
                page += 1
                self.driver.get(f'https://www.decolar.com/accommodations/results/CIT_{id_destino_decolar}/{checkin}/{checkout}/{pax}?from=SB2&facet=city&searchId=2c403941-a9b6-457f-a17e-5f3131886e89&page={page}')
                print(f'\u001b[32m{"Navegando para a próxima página"}\u001b[0m')
                sleep(2)
            except:
                self.driver.quit()
        
        print(f'\u001b[32m{"Resultados:"}\u001b[0m')
        print(self.lista_nome_hoteis)
        print(self.lista_preco_hoteis)

        for nome in self.lista_nome_hoteis:
            nome_hoteis_desp.append(nome)
        for preco in self.lista_preco_hoteis:
            preco_hoteis_desp.append(preco)

start = ScrappyDesp()
start.iniciar()
# Out:
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Navegando para a próxima página
# Resultados:
# ['Go Inn Hotel Curitiba', 'Golden Park Curitiba', 'Victoria Villa Curitiba', 'Nacional Inn Curitiba Torres', 'Dan Inn Curitiba Hotel', 'Grand Mercure Rayon', 'Bourbon Curitiba Convention Hotel', 'Mabu Curitiba Business', 'Roochelle Corporate Hotel', 'Hotel Flat Petras Residence', 'Radisson Hotel Curitiba', 'Master Curitiba', 'Rede Andrade Braz', 'Nacional Inn Curitiba Estação', 'Intercity Curitiba - Centro Cívico', 'Rio Hotel by Bourbon Curitiba Batel', 'Transamerica Prime Batel', 'Quality Hotel Curitiba', 'Pestana Curitiba', 'Novotel Curitiba Batel', 'Mercure Curitiba Batel', 'Ibis Curitiba Batel', 'Full Jazz by Slaviero Hotéis', 'Bristol Brasil 500 Hotel', 'Slaviero Essential Curitiba Centro', 'Lancaster Hotel', 'San Juan Executive Curitiba', 'Blue Tree Towers Batel - Curitiba', 'Slim Curitiba Av. das Torres by Slaviero Hotéis', 'Nomaa Hotel', 'Ibis Styles Curitiba Batel', 'Trevi Hotel & Business', 'Ibis Styles Curitiba Santa Felicidade', 'Mercure Curitiba Sete de Setembro', 'Ibis Styles Curitiba Centro Cívico', 'Bristol Centro Cívico', 'Slim Curitiba Alto da XV by Slaviero Hotéis', 'Slaviero Essential Curitiba Batel', 'Blue Tree Towers Saint Michel - Curitiba', 'Intercity Curitiba Batel', 'Hotel ibis Curitiba Shopping', 'Mercure Curitiba Golden', 'Slaviero Essential Curitiba Shopping', 'San Juan Johnscher', 'Slim Curitiba João Bettega by Slaviero Hotéis', 'Deville Curitiba Batel', 'Hotel Confiance Batel', 'Slaviero Essential Curitiba Aeroporto', 'Ibis Budget Curitiba Centro', 'Hotel Confiance Centro Cívico', 'Rockefeller by Slaviero Hotéis', 'San Juan Royal', 'Bristol Upper Residence', 'Hollyster Hotel', 'Hotel Centro Europeu', 'Curitiba The Five', 'Bristol Metropolitan Hotel', 'Bristol Portal do Iguaçu', 'Alta Reggia Plaza Hotel', 'Hotel Moov Curitiba', 'Hotel Sol', 'Hotel Aladdin', 'Lizon Curitiba', 'Hara Palace Hotel', 'Saint Emilion Hotel', 'Nikko Hotel', 'Hotel Confiance Soho Batel', 'Caravelle Palace Hotel', 'Rede Andrade Vernon', 'Granville Hotel', 'Golden Star Hotel', 'San Martin Hotel Curitiba', 'Hotel Estação Express', 'Hotel Confiance Prime Batel', 'Rede Andrade CWB', 'Hotel Tibagi', 'Rede Andrade Mercado', 'Hotel 10 Curitiba', 'Hotel Itamaraty', 'Pleione Residence', 'Euro Hotel', 'SLIM CURITIBA JOAO BETTEGA', 'Hostel Social', 'Intercity Curitiba Batel', 'Del Rey Hotel', 'Maua Hotel', 'Hotel Wynn Batel', 'Hospedagem Three Little Birds', '7th Avenue Oxford Residence', 'B.Living', 'Esquina Batel Hotel', 'Hotel Confiance Barigui', 'Hotel Pinheirinho', 'Bela Curitiba Hostel', 'Hotel Nova Lisboa', 'Curitiba Casa Hostel', 'All You Need', 'Villa Tata Suites', 'Morada Clariana']
# ['420', '250', '386', '308', '354', '568', '636', '422', '262', '636', '766', '362', '678', '310', '482', '428', '588', '506', '672', '590', '624', '332', '632', '610', '550', '382', '390', '570', '444', '1.558', '352', '342', '434', '472', '330', '452', '456', '516', '420', '462', '382', '532', '514', '494', '376', '462', '552', '410', '314', '504', '502', '478', '342', '380', '436', '724', '418', '322', '404', '338', '282', '316', '416', '262', '422', '400', '456', '284', '242', '318', '420', '316', '312', '480', '238', '318', '224', '540', '270', '356', '182', '462', '258', '460', '460', '364', '578', '362', '418', '440', '276', '578', '210', '328', '192', '316', '564', '272', '482']

# %%
# Lista nome hotéis

print(nome_hoteis_desp)
# Out:
# ['Go Inn Hotel Curitiba', 'Golden Park Curitiba', 'Victoria Villa Curitiba', 'Nacional Inn Curitiba Torres', 'Dan Inn Curitiba Hotel', 'Grand Mercure Rayon', 'Bourbon Curitiba Convention Hotel', 'Mabu Curitiba Business', 'Roochelle Corporate Hotel', 'Hotel Flat Petras Residence', 'Radisson Hotel Curitiba', 'Master Curitiba', 'Rede Andrade Braz', 'Nacional Inn Curitiba Estação', 'Intercity Curitiba - Centro Cívico', 'Rio Hotel by Bourbon Curitiba Batel', 'Transamerica Prime Batel', 'Quality Hotel Curitiba', 'Pestana Curitiba', 'Novotel Curitiba Batel', 'Mercure Curitiba Batel', 'Ibis Curitiba Batel', 'Full Jazz by Slaviero Hotéis', 'Bristol Brasil 500 Hotel', 'Slaviero Essential Curitiba Centro', 'Lancaster Hotel', 'San Juan Executive Curitiba', 'Blue Tree Towers Batel - Curitiba', 'Slim Curitiba Av. das Torres by Slaviero Hotéis', 'Nomaa Hotel', 'Ibis Styles Curitiba Batel', 'Trevi Hotel & Business', 'Ibis Styles Curitiba Santa Felicidade', 'Mercure Curitiba Sete de Setembro', 'Ibis Styles Curitiba Centro Cívico', 'Bristol Centro Cívico', 'Slim Curitiba Alto da XV by Slaviero Hotéis', 'Slaviero Essential Curitiba Batel', 'Blue Tree Towers Saint Michel - Curitiba', 'Intercity Curitiba Batel', 'Hotel ibis Curitiba Shopping', 'Mercure Curitiba Golden', 'Slaviero Essential Curitiba Shopping', 'San Juan Johnscher', 'Slim Curitiba João Bettega by Slaviero Hotéis', 'Deville Curitiba Batel', 'Hotel Confiance Batel', 'Slaviero Essential Curitiba Aeroporto', 'Ibis Budget Curitiba Centro', 'Hotel Confiance Centro Cívico', 'Rockefeller by Slaviero Hotéis', 'San Juan Royal', 'Bristol Upper Residence', 'Hollyster Hotel', 'Hotel Centro Europeu', 'Curitiba The Five', 'Bristol Metropolitan Hotel', 'Bristol Portal do Iguaçu', 'Alta Reggia Plaza Hotel', 'Hotel Moov Curitiba', 'Hotel Sol', 'Hotel Aladdin', 'Lizon Curitiba', 'Hara Palace Hotel', 'Saint Emilion Hotel', 'Nikko Hotel', 'Hotel Confiance Soho Batel', 'Caravelle Palace Hotel', 'Rede Andrade Vernon', 'Granville Hotel', 'Golden Star Hotel', 'San Martin Hotel Curitiba', 'Hotel Estação Express', 'Hotel Confiance Prime Batel', 'Rede Andrade CWB', 'Hotel Tibagi', 'Rede Andrade Mercado', 'Hotel 10 Curitiba', 'Hotel Itamaraty', 'Pleione Residence', 'Euro Hotel', 'SLIM CURITIBA JOAO BETTEGA', 'Hostel Social', 'Intercity Curitiba Batel', 'Del Rey Hotel', 'Maua Hotel', 'Hotel Wynn Batel', 'Hospedagem Three Little Birds', '7th Avenue Oxford Residence', 'B.Living', 'Esquina Batel Hotel', 'Hotel Confiance Barigui', 'Hotel Pinheirinho', 'Bela Curitiba Hostel', 'Hotel Nova Lisboa', 'Curitiba Casa Hostel', 'All You Need', 'Villa Tata Suites', 'Morada Clariana']

# %%
# Lista preço hotéis

print(preco_hoteis_desp)
# Out:
# ['420', '250', '386', '308', '354', '568', '636', '422', '262', '636', '766', '362', '678', '310', '482', '428', '588', '506', '672', '590', '624', '332', '632', '610', '550', '382', '390', '570', '444', '1.558', '352', '342', '434', '472', '330', '452', '456', '516', '420', '462', '382', '532', '514', '494', '376', '462', '552', '410', '314', '504', '502', '478', '342', '380', '436', '724', '418', '322', '404', '338', '282', '316', '416', '262', '422', '400', '456', '284', '242', '318', '420', '316', '312', '480', '238', '318', '224', '540', '270', '356', '182', '462', '258', '460', '460', '364', '578', '362', '418', '440', '276', '578', '210', '328', '192', '316', '564', '272', '482']

# %%
# Tratamento formato

preco_hoteis_desp_nofloat = []
for x in preco_hoteis_desp:
    item = x
    for y in ["."]:
        item = item.replace(y, "")
    preco_hoteis_desp_nofloat.append(item)
print(preco_hoteis_desp_nofloat)
# Out:
# ['420', '250', '386', '308', '354', '568', '636', '422', '262', '636', '766', '362', '678', '310', '482', '428', '588', '506', '672', '590', '624', '332', '632', '610', '550', '382', '390', '570', '444', '1558', '352', '342', '434', '472', '330', '452', '456', '516', '420', '462', '382', '532', '514', '494', '376', '462', '552', '410', '314', '504', '502', '478', '342', '380', '436', '724', '418', '322', '404', '338', '282', '316', '416', '262', '422', '400', '456', '284', '242', '318', '420', '316', '312', '480', '238', '318', '224', '540', '270', '356', '182', '462', '258', '460', '460', '364', '578', '362', '418', '440', '276', '578', '210', '328', '192', '316', '564', '272', '482']

# %%
# Tratamento formato

preco_hoteis_desp_num = pd.to_numeric(preco_hoteis_desp_nofloat, errors='coerce')
print(preco_hoteis_desp_num)
# Out:
# [ 420  250  386  308  354  568  636  422  262  636  766  362  678  310
#   482  428  588  506  672  590  624  332  632  610  550  382  390  570
#   444 1558  352  342  434  472  330  452  456  516  420  462  382  532
#   514  494  376  462  552  410  314  504  502  478  342  380  436  724
#   418  322  404  338  282  316  416  262  422  400  456  284  242  318
#   420  316  312  480  238  318  224  540  270  356  182  462  258  460
#   460  364  578  362  418  440  276  578  210  328  192  316  564  272
#   482]

# %%
# Mesclagem nomes e preços em dicionário

data_hoteis_desp = []
for el in zip(nome_hoteis_desp, preco_hoteis_desp_num):
    data_hoteis_desp.append(el)
data_hoteis_desp_dict = dict(data_hoteis_desp)
print(data_hoteis_desp_dict)
# Out:
# {'Go Inn Hotel Curitiba': 420, 'Golden Park Curitiba': 250, 'Victoria Villa Curitiba': 386, 'Nacional Inn Curitiba Torres': 308, 'Dan Inn Curitiba Hotel': 354, 'Grand Mercure Rayon': 568, 'Bourbon Curitiba Convention Hotel': 636, 'Mabu Curitiba Business': 422, 'Roochelle Corporate Hotel': 262, 'Hotel Flat Petras Residence': 636, 'Radisson Hotel Curitiba': 766, 'Master Curitiba': 362, 'Rede Andrade Braz': 678, 'Nacional Inn Curitiba Estação': 310, 'Intercity Curitiba - Centro Cívico': 482, 'Rio Hotel by Bourbon Curitiba Batel': 428, 'Transamerica Prime Batel': 588, 'Quality Hotel Curitiba': 506, 'Pestana Curitiba': 672, 'Novotel Curitiba Batel': 590, 'Mercure Curitiba Batel': 624, 'Ibis Curitiba Batel': 332, 'Full Jazz by Slaviero Hotéis': 632, 'Bristol Brasil 500 Hotel': 610, 'Slaviero Essential Curitiba Centro': 550, 'Lancaster Hotel': 382, 'San Juan Executive Curitiba': 390, 'Blue Tree Towers Batel - Curitiba': 570, 'Slim Curitiba Av. das Torres by Slaviero Hotéis': 444, 'Nomaa Hotel': 1558, 'Ibis Styles Curitiba Batel': 352, 'Trevi Hotel & Business': 342, 'Ibis Styles Curitiba Santa Felicidade': 434, 'Mercure Curitiba Sete de Setembro': 472, 'Ibis Styles Curitiba Centro Cívico': 330, 'Bristol Centro Cívico': 452, 'Slim Curitiba Alto da XV by Slaviero Hotéis': 456, 'Slaviero Essential Curitiba Batel': 516, 'Blue Tree Towers Saint Michel - Curitiba': 420, 'Intercity Curitiba Batel': 460, 'Hotel ibis Curitiba Shopping': 382, 'Mercure Curitiba Golden': 532, 'Slaviero Essential Curitiba Shopping': 514, 'San Juan Johnscher': 494, 'Slim Curitiba João Bettega by Slaviero Hotéis': 376, 'Deville Curitiba Batel': 462, 'Hotel Confiance Batel': 552, 'Slaviero Essential Curitiba Aeroporto': 410, 'Ibis Budget Curitiba Centro': 314, 'Hotel Confiance Centro Cívico': 504, 'Rockefeller by Slaviero Hotéis': 502, 'San Juan Royal': 478, 'Bristol Upper Residence': 342, 'Hollyster Hotel': 380, 'Hotel Centro Europeu': 436, 'Curitiba The Five': 724, 'Bristol Metropolitan Hotel': 418, 'Bristol Portal do Iguaçu': 322, 'Alta Reggia Plaza Hotel': 404, 'Hotel Moov Curitiba': 338, 'Hotel Sol': 282, 'Hotel Aladdin': 316, 'Lizon Curitiba': 416, 'Hara Palace Hotel': 262, 'Saint Emilion Hotel': 422, 'Nikko Hotel': 400, 'Hotel Confiance Soho Batel': 456, 'Caravelle Palace Hotel': 284, 'Rede Andrade Vernon': 242, 'Granville Hotel': 318, 'Golden Star Hotel': 420, 'San Martin Hotel Curitiba': 316, 'Hotel Estação Express': 312, 'Hotel Confiance Prime Batel': 480, 'Rede Andrade CWB': 238, 'Hotel Tibagi': 318, 'Rede Andrade Mercado': 224, 'Hotel 10 Curitiba': 540, 'Hotel Itamaraty': 270, 'Pleione Residence': 356, 'Euro Hotel': 182, 'SLIM CURITIBA JOAO BETTEGA': 462, 'Hostel Social': 258, 'Del Rey Hotel': 460, 'Maua Hotel': 364, 'Hotel Wynn Batel': 578, 'Hospedagem Three Little Birds': 362, '7th Avenue Oxford Residence': 418, 'B.Living': 440, 'Esquina Batel Hotel': 276, 'Hotel Confiance Barigui': 578, 'Hotel Pinheirinho': 210, 'Bela Curitiba Hostel': 328, 'Hotel Nova Lisboa': 192, 'Curitiba Casa Hostel': 316, 'All You Need': 564, 'Villa Tata Suites': 272, 'Morada Clariana': 482}

# %%
# Conversão dicionário para dataframe

df_data_hoteis_desp = pd.DataFrame(list(data_hoteis_desp_dict.items()),
                   columns=['Nome', 'Preço Decolar'])
display(df_data_hoteis_desp)
# Out:
#                             Nome  Preço Decolar
# 0          Go Inn Hotel Curitiba            420
# 1           Golden Park Curitiba            250
# 2        Victoria Villa Curitiba            386
# 3   Nacional Inn Curitiba Torres            308
# 4         Dan Inn Curitiba Hotel            354
# ..                           ...            ...
# 93             Hotel Nova Lisboa            192
# 94          Curitiba Casa Hostel            316
# 95                  All You Need            564
# 96             Villa Tata Suites            272
# 97               Morada Clariana            482
#
# [98 rows x 2 columns]

# %%
# Merge data

data_merge = pd.merge(df_data_hoteis_cvc, df_data_hoteis_desp, on=['Nome'], how='left')
display(data_merge)
# Out:
#                                Nome  Preço CVC  Preço Decolar
# 0                      Hotel Tibagi        222          318.0
# 1                   Hotel Granville        244            NaN
# 2                 Hotel Pinheirinho        274          210.0
# 3              Golden Park Curitiba        278          250.0
# 4           Master Express Curitiba        316            NaN
# ..                              ...        ...            ...
# 64           Quality Hotel Curitiba        704          506.0
# 65           Novotel Curitiba Batel        726          590.0
# 66  Blue Tree Towers Batel Curitiba        778            NaN
# 67          Radisson Hotel Curitiba        788          766.0
# 68                      Nomaa Hotel       1258         1558.0
#
# [69 rows x 3 columns]

# %%
# Limpeza NaN

data_merge_notna = data_merge.dropna()
display(data_merge_notna)
# Out:
#                                         Nome  Preço CVC  Preço Decolar
# 0                               Hotel Tibagi        222          318.0
# 2                          Hotel Pinheirinho        274          210.0
# 3                       Golden Park Curitiba        278          250.0
# 5                     Caravelle Palace Hotel        318          284.0
# 7                Ibis Budget Curitiba Centro        322          314.0
# 8              Nacional Inn Curitiba Estação        324          310.0
# 9                        Ibis Curitiba Batel        332          332.0
# 10                Ibis Styles Curitiba Batel        346          352.0
# 11              Nacional Inn Curitiba Torres        352          308.0
# 17               San Juan Executive Curitiba        386          390.0
# 19        Ibis Styles Curitiba Centro Cívico        388          330.0
# 21                   Alta Reggia Plaza Hotel        404          404.0
# 22                             Hotel Aladdin        406          316.0
# 23  Blue Tree Towers Saint Michel - Curitiba        418          420.0
# 24                   Victoria Villa Curitiba        426          386.0
# 25                       Saint Emilion Hotel        430          422.0
# 26     Ibis Styles Curitiba Santa Felicidade        432          434.0
# 28                    Mabu Curitiba Business        434          422.0
# 29                       Hotel Moov Curitiba        446          338.0
# 30                     Bristol Centro Cívico        450          452.0
# 32                    Trevi Hotel & Business        454          342.0
# 34                    Deville Curitiba Batel        460          462.0
# 44                                 Hotel Sol        492          282.0
# 46      Slaviero Essential Curitiba Shopping        502          514.0
# 47         Slaviero Essential Curitiba Batel        504          516.0
# 50                   Mercure Curitiba Golden        518          532.0
# 52         Bourbon Curitiba Convention Hotel        540          636.0
# 53        Slaviero Essential Curitiba Centro        548          550.0
# 55                   Hotel Confiance Barigui        564          578.0
# 60                      Hotel Centro Europeu        654          436.0
# 61                    Mercure Curitiba Batel        676          624.0
# 64                    Quality Hotel Curitiba        704          506.0
# 65                    Novotel Curitiba Batel        726          590.0
# 67                   Radisson Hotel Curitiba        788          766.0
# 68                               Nomaa Hotel       1258         1558.0

# %%
# Comparação de preços

rate_comparison = data_merge_notna
display(rate_comparison)
# Out:
#                                         Nome  Preço CVC  Preço Decolar
# 0                               Hotel Tibagi        222          318.0
# 2                          Hotel Pinheirinho        274          210.0
# 3                       Golden Park Curitiba        278          250.0
# 5                     Caravelle Palace Hotel        318          284.0
# 7                Ibis Budget Curitiba Centro        322          314.0
# 8              Nacional Inn Curitiba Estação        324          310.0
# 9                        Ibis Curitiba Batel        332          332.0
# 10                Ibis Styles Curitiba Batel        346          352.0
# 11              Nacional Inn Curitiba Torres        352          308.0
# 17               San Juan Executive Curitiba        386          390.0
# 19        Ibis Styles Curitiba Centro Cívico        388          330.0
# 21                   Alta Reggia Plaza Hotel        404          404.0
# 22                             Hotel Aladdin        406          316.0
# 23  Blue Tree Towers Saint Michel - Curitiba        418          420.0
# 24                   Victoria Villa Curitiba        426          386.0
# 25                       Saint Emilion Hotel        430          422.0
# 26     Ibis Styles Curitiba Santa Felicidade        432          434.0
# 28                    Mabu Curitiba Business        434          422.0
# 29                       Hotel Moov Curitiba        446          338.0
# 30                     Bristol Centro Cívico        450          452.0
# 32                    Trevi Hotel & Business        454          342.0
# 34                    Deville Curitiba Batel        460          462.0
# 44                                 Hotel Sol        492          282.0
# 46      Slaviero Essential Curitiba Shopping        502          514.0
# 47         Slaviero Essential Curitiba Batel        504          516.0
# 50                   Mercure Curitiba Golden        518          532.0
# 52         Bourbon Curitiba Convention Hotel        540          636.0
# 53        Slaviero Essential Curitiba Centro        548          550.0
# 55                   Hotel Confiance Barigui        564          578.0
# 60                      Hotel Centro Europeu        654          436.0
# 61                    Mercure Curitiba Batel        676          624.0
# 64                    Quality Hotel Curitiba        704          506.0
# 65                    Novotel Curitiba Batel        726          590.0
# 67                   Radisson Hotel Curitiba        788          766.0
# 68                               Nomaa Hotel       1258         1558.0

# %%
rate_comparison['% Diferença'] = 0
for el in rate_comparison:
    dif = (rate_comparison['Preço Decolar'] / rate_comparison['Preço CVC'] -1 ) * 100
    rate_comparison['% Diferença'] = round(dif, 0)
display(rate_comparison)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                         Nome  ...  % Diferença
# 0                               Hotel Tibagi  ...         43.0
# 2                          Hotel Pinheirinho  ...        -23.0
# 3                       Golden Park Curitiba  ...        -10.0
# 5                     Caravelle Palace Hotel  ...        -11.0
# 7                Ibis Budget Curitiba Centro  ...         -2.0
# 8              Nacional Inn Curitiba Estação  ...         -4.0
# 9                        Ibis Curitiba Batel  ...          0.0
# 10                Ibis Styles Curitiba Batel  ...          2.0
# 11              Nacional Inn Curitiba Torres  ...        -12.0
# 17               San Juan Executive Curitiba  ...          1.0
# 19        Ibis Styles Curitiba Centro Cívico  ...        -15.0
# 21                   Alta Reggia Plaza Hotel  ...          0.0
# 22                             Hotel Aladdin  ...        -22.0
# 23  Blue Tree Towers Saint Michel - Curitiba  ...          0.0
# 24                   Victoria Villa Curitiba  ...         -9.0
# 25                       Saint Emilion Hotel  ...         -2.0
# 26     Ibis Styles Curitiba Santa Felicidade  ...          0.0
# 28                    Mabu Curitiba Business  ...         -3.0
# 29                       Hotel Moov Curitiba  ...        -24.0
# 30                     Bristol Centro Cívico  ...          0.0
# 32                    Trevi Hotel & Business  ...        -25.0
# 34                    Deville Curitiba Batel  ...          0.0
# 44                                 Hotel Sol  ...        -43.0
# 46      Slaviero Essential Curitiba Shopping  ...          2.0
# 47         Slaviero Essential Curitiba Batel  ...          2.0
# 50                   Mercure Curitiba Golden  ...          3.0
# 52         Bourbon Curitiba Convention Hotel  ...         18.0
# 53        Slaviero Essential Curitiba Centro  ...          0.0
# 55                   Hotel Confiance Barigui  ...          2.0
# 60                      Hotel Centro Europeu  ...        -33.0
# 61                    Mercure Curitiba Batel  ...         -8.0
# 64                    Quality Hotel Curitiba  ...        -28.0
# 65                    Novotel Curitiba Batel  ...        -19.0
# 67                   Radisson Hotel Curitiba  ...         -3.0
# 68                               Nomaa Hotel  ...         24.0
#
# [35 rows x 4 columns]

# %%
# Conversão dataframe para XLSX

writer = pd.ExcelWriter('report.xlsx')
rate_comparison.to_excel(writer, 'Pricing-Decolar-CVC', index=False)
writer.save()

# %%
# Download XLSX

from google.colab import files
files.download("report.xlsx")
